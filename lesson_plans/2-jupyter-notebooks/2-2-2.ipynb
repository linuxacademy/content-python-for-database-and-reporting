# %% [markdown]
# # pandas Dataframes

# %% [markdown]
# ### Import packages

# %%
import pandas as pd

# %% [markdown]
# ### Creating a Basic Dataframe From JSON

# %%
# define the data as a list
data = [
    ("Dexter","Johnsons","dog","shiba inu","red sesame",1.5,35,"m",False,"both",True),
    ("Alfred","Johnsons","cat","mix","tuxedo",4,12,"m",True,"indoor",True),
    ("Petra","Smith","cat","ragdoll","calico",None,10,"f",False,"both",True),
    ("Ava","Smith","dog","mix","blk/wht",12,32,"f",True,"both",False),
    ("Schroder","Brown","cat","mix","orange",13,15,"m",False,"indoor",True),
    ("Blackbeard","Brown","bird","parrot","multi",5,3,"f",False,"indoor",),
]

# define the labels
labels = ["name","owner","type","breed","color","age","weight","gender","health issues","indoor/outboor","vaccinated"]

# create dataframe
vet_records = pd.DataFrame.from_records(data, columns=labels)

# %%
vet_records.head()
# Out:
#        name     owner type      breed       color   age  weight gender  \
# 0    Dexter  Johnsons  dog  shiba inu  red sesame   1.5      35      m
# 1    Alfred  Johnsons  cat        mix      tuxedo   4.0      12      m
# 2     Petra     Smith  cat    ragdoll      calico   NaN      10      f
# 3       Ava     Smith  dog        mix     blk/wht  12.0      32      f
# 4  Schroder     Brown  cat        mix      orange  13.0      15      m
#
#    health issues indoor/outboor vaccinated
# 0          False           both       True
# 1           True         indoor       True
# 2          False           both       True
# 3           True           both      False
# 4          False         indoor       True

# %%
vet_records.tail()
# Out:
#          name     owner  type    breed    color   age  weight gender  \
# 1      Alfred  Johnsons   cat      mix   tuxedo   4.0      12      m
# 2       Petra     Smith   cat  ragdoll   calico   NaN      10      f
# 3         Ava     Smith   dog      mix  blk/wht  12.0      32      f
# 4    Schroder     Brown   cat      mix   orange  13.0      15      m
# 5  Blackbeard     Brown  bird   parrot    multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated
# 1           True         indoor       True
# 2          False           both       True
# 3           True           both      False
# 4          False         indoor       True
# 5          False         indoor       None

# %%
vet_records
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      35      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico   NaN      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated
# 0          False           both       True
# 1           True         indoor       True
# 2          False           both       True
# 3           True           both      False
# 4          False         indoor       True
# 5          False         indoor       None

# %%
vet_records.dtypes
# Out:
# name               object
# owner              object
# type               object
# breed              object
# color              object
# age               float64
# weight              int64
# gender             object
# health issues        bool
# indoor/outboor     object
# vaccinated         object
# dtype: object

# %%
vet_records.describe()
# Out:
#             age     weight
# count   5.00000   6.000000
# mean    7.10000  17.833333
# std     5.10392  12.797135
# min     1.50000   3.000000
# 25%     4.00000  10.500000
# 50%     5.00000  13.500000
# 75%    12.00000  27.750000
# max    13.00000  35.000000

# %%
vet_records.describe(include='all')
# Out:
#             name  owner type breed    color       age     weight gender  \
# count          6      6    6     6        6   5.00000   6.000000      6
# unique         6      3    3     4        6       NaN        NaN      2
# top     Schroder  Brown  cat   mix  blk/wht       NaN        NaN      m
# freq           1      2    3     3        1       NaN        NaN      3
# mean         NaN    NaN  NaN   NaN      NaN   7.10000  17.833333    NaN
# std          NaN    NaN  NaN   NaN      NaN   5.10392  12.797135    NaN
# min          NaN    NaN  NaN   NaN      NaN   1.50000   3.000000    NaN
# 25%          NaN    NaN  NaN   NaN      NaN   4.00000  10.500000    NaN
# 50%          NaN    NaN  NaN   NaN      NaN   5.00000  13.500000    NaN
# 75%          NaN    NaN  NaN   NaN      NaN  12.00000  27.750000    NaN
# max          NaN    NaN  NaN   NaN      NaN  13.00000  35.000000    NaN
#
#        health issues indoor/outboor vaccinated
# count              6              6          5
# unique             2              2          2
# top            False           both       True
# freq               4              3          4
# mean             NaN            NaN        NaN
# std              NaN            NaN        NaN
# min              NaN            NaN        NaN
# 25%              NaN            NaN        NaN
# 50%              NaN            NaN        NaN
# 75%              NaN            NaN        NaN
# max              NaN            NaN        NaN

# %%
vet_records = vet_records.assign(age_weight=(vet_records['age']/vet_records['weight']))

# %%
vet_records
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      35      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico   NaN      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both       True    0.042857
# 1           True         indoor       True    0.333333
# 2          False           both       True         NaN
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667
# 5          False         indoor       None    1.666667

# %%
vet_records.dtypes
# Out:
# name               object
# owner              object
# type               object
# breed              object
# color              object
# age               float64
# weight              int64
# gender             object
# health issues        bool
# indoor/outboor     object
# vaccinated         object
# age_weight        float64
# dtype: object

# %%
vet_records.at[5, "vaccinated"] = False

# %%
vet_records
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico   NaN      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 1           True         indoor       True    0.333333
# 2          False           both       True         NaN
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667
# 5          False         indoor      False    1.666667

# %% [markdown]
# # Part Duex

# %%
vet_records.at[0, "weight"] = 34.7

# %%
vet_records
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico   NaN      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both       True    0.042857
# 1           True         indoor       True    0.333333
# 2          False           both       True         NaN
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667
# 5          False         indoor       None    1.666667

# %%
vet_records.dtypes
# Out:
# name               object
# owner              object
# type               object
# breed              object
# color              object
# age               float64
# weight              int64
# gender             object
# health issues        bool
# indoor/outboor     object
# vaccinated         object
# age_weight        float64
# dtype: object

# %%
weight = vet_records['weight']

# %%
weight
# Out:
# 0    34
# 1    12
# 2    10
# 3    32
# 4    15
# 5     3
# Name: weight, dtype: int64

# %%
type(weight)
# Out:
# pandas.core.series.Series

# %%
type(vet_records)
# Out:
# pandas.core.frame.DataFrame

# %%
dog_weight = vet_records[vet_records.type=='dog']

# %%
dog_weight
# Out:
#      name     owner type      breed       color   age  weight gender  \
# 0  Dexter  Johnsons  dog  shiba inu  red sesame   1.5      34      m
# 3     Ava     Smith  dog        mix     blk/wht  12.0      32      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both       True    0.042857
# 3           True           both      False    0.375000

# %%
vet_records.type.count()
# Out:
# 6

# %%
vet_records.groupby('type').count()
# Out:
#       name  owner  breed  color  age  weight  gender  health issues  \
# type
# bird     1      1      1      1    1       1       1              1
# cat      3      3      3      3    2       3       3              3
# dog      2      2      2      2    2       2       2              2
#
#       indoor/outboor  vaccinated  age_weight
# type
# bird               1           0           1
# cat                3           3           2
# dog                2           2           2

# %%
vet_records.type.value_counts()
# Out:
# cat     3
# dog     2
# bird    1
# Name: type, dtype: int64

# %%
vet_records.loc[1,["name", "owner"]]
# Out:
# name       Alfred
# owner    Johnsons
# Name: 1, dtype: object

# %%
vet_records.iloc[:,0]
# Out:
# 0        Dexter
# 1        Alfred
# 2         Petra
# 3           Ava
# 4      Schroder
# 5    Blackbeard
# Name: name, dtype: object

# %%
vet_records.iloc[2,0]
# Out:
# 'Petra'

# %%
vet_records.iloc[[2,3],[4,5]]
# Out:
#      color   age
# 2   calico   NaN
# 3  blk/wht  12.0

# %% [markdown]
# loc iloc boolean mask isnan: https://stackoverflow.com/questions/13295735/how-can-i-replace-all-the-nan-values-with-zeros-in-a-column-of-a-pandas-datafra

# %%
vet_records[vet_records.name=='Dexter']
# Out:
#      name     owner type      breed       color  age  weight gender  \
# 0  Dexter  Johnsons  dog  shiba inu  red sesame  1.5      34      m
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857

# %%
vet_records[vet_records.name.isin(['Dexter','Blackbeard'])]
# Out:
#          name     owner  type      breed       color  age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame  1.5      34      m
# 5  Blackbeard     Brown  bird     parrot       multi  5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 5          False         indoor      False    1.666667

# %%
vet_records[~vet_records.name.isin(['Dexter','Blackbeard'])]
# Out:
#        name     owner type    breed    color   age  weight gender  \
# 1    Alfred  Johnsons  cat      mix   tuxedo   4.0      12      m
# 2     Petra     Smith  cat  ragdoll   calico   NaN      10      f
# 3       Ava     Smith  dog      mix  blk/wht  12.0      32      f
# 4  Schroder     Brown  cat      mix   orange  13.0      15      m
#
#    health issues indoor/outboor vaccinated  age_weight
# 1           True         indoor       True    0.333333
# 2          False           both       True         NaN
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667

# %%
mask = vet_records[vet_records.gender=='m']

# %%
print(mask)
# Out:
#        name     owner type      breed       color   age  weight gender  \
# 0    Dexter  Johnsons  dog  shiba inu  red sesame   1.5      34      m
# 1    Alfred  Johnsons  cat        mix      tuxedo   4.0      12      m
# 4  Schroder     Brown  cat        mix      orange  13.0      15      m
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 1           True         indoor       True    0.333333
# 4          False         indoor       True    0.866667

# %%
mask = vet_records.gender=='m'

# %%
mask
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# Name: gender, dtype: bool

# %%
vet_records[mask]
# Out:
#        name     owner type      breed       color   age  weight gender  \
# 0    Dexter  Johnsons  dog  shiba inu  red sesame   1.5      34      m
# 1    Alfred  Johnsons  cat        mix      tuxedo   4.0      12      m
# 4  Schroder     Brown  cat        mix      orange  13.0      15      m
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 1           True         indoor       True    0.333333
# 4          False         indoor       True    0.866667

# %%
vet_records
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico  12.0      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 1           True         indoor       True    0.333333
# 2          False           both       True         NaN
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667
# 5          False         indoor       None    1.666667

# %%
vet_records.isna()
# Out:
#     name  owner   type  breed  color    age  weight  gender  health issues  \
# 0  False  False  False  False  False  False   False   False          False
# 1  False  False  False  False  False  False   False   False          False
# 2  False  False  False  False  False   True   False   False          False
# 3  False  False  False  False  False  False   False   False          False
# 4  False  False  False  False  False  False   False   False          False
# 5  False  False  False  False  False  False   False   False          False
#
#    indoor/outboor  vaccinated  age_weight
# 0           False       False       False
# 1           False       False       False
# 2           False       False        True
# 3           False       False       False
# 4           False       False       False
# 5           False       False       False

# %%
vet_records
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico   NaN      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 1           True         indoor       True    0.333333
# 2          False           both       True         NaN
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667
# 5          False         indoor      False    1.666667

# %%
vet_records.at[5,"vaccinated"] = None

# %%
vet_records
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico   NaN      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 1           True         indoor       True    0.333333
# 2          False           both       True         NaN
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667
# 5          False         indoor       None    1.666667

# %%
vet_records.isna()
# Out:
#     name  owner   type  breed  color    age  weight  gender  health issues  \
# 0  False  False  False  False  False  False   False   False          False
# 1  False  False  False  False  False  False   False   False          False
# 2  False  False  False  False  False   True   False   False          False
# 3  False  False  False  False  False  False   False   False          False
# 4  False  False  False  False  False  False   False   False          False
# 5  False  False  False  False  False  False   False   False          False
#
#    indoor/outboor  vaccinated  age_weight
# 0           False       False       False
# 1           False       False       False
# 2           False       False        True
# 3           False       False       False
# 4           False       False       False
# 5           False        True       False

# %%
vet_records_example = vet_records

# %%
vet_records_example
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico   NaN      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 1           True         indoor       True    0.333333
# 2          False           both       True         NaN
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667
# 5          False         indoor       None    1.666667

# %%
vet_records_example.fillna(0)
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico   0.0      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor vaccinated  age_weight
# 0          False           both      False    0.042857
# 1           True         indoor       True    0.333333
# 2          False           both       True    0.000000
# 3           True           both      False    0.375000
# 4          False         indoor       True    0.866667
# 5          False         indoor          0    1.666667

# %%
values = {"age": 12, "vaccinated": False, "age_weight": vet_records['age']/vet_records['weight']}

# %%
vet_records.fillna(value=values)
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico  12.0      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor  vaccinated  age_weight
# 0          False           both       False    0.042857
# 1           True         indoor        True    0.333333
# 2          False           both        True         NaN
# 3           True           both       False    0.375000
# 4          False         indoor        True    0.866667
# 5          False         indoor       False    1.666667

# %%
vet_records_na = vet_records.fillna(value=values)

# %%
vet_records_na
# Out:
#          name     owner  type      breed       color   age  weight gender  \
# 0      Dexter  Johnsons   dog  shiba inu  red sesame   1.5      34      m
# 1      Alfred  Johnsons   cat        mix      tuxedo   4.0      12      m
# 2       Petra     Smith   cat    ragdoll      calico  12.0      10      f
# 3         Ava     Smith   dog        mix     blk/wht  12.0      32      f
# 4    Schroder     Brown   cat        mix      orange  13.0      15      m
# 5  Blackbeard     Brown  bird     parrot       multi   5.0       3      f
#
#    health issues indoor/outboor  vaccinated  age_weight
# 0          False           both       False    0.042857
# 1           True         indoor        True    0.333333
# 2          False           both        True         NaN
# 3           True           both       False    0.375000
# 4          False         indoor        True    0.866667
# 5          False         indoor       False    1.666667

# %% [markdown]
# Notice the equation did not work.  There are two ways to fix calculate the value and add to values or us `.at`  The best option is to deal with NaN before making making any other changes to the data
